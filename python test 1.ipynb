# %% [markdown]
# 1)What is Python? What are the benefits of using Python
# python is a high level lanuguage.it can be user undestable lanuguage.
# It was created by gudio van rousm.
# Benfits:it is easy to understand
# it is used in game development and also artficial intelagence
#
# 2)What are lists and tuples? What is the key difference between the two
#     LIST:
#     list is a collection of elements ,items and values.
#     it is mutable
#     it denotes as a [].separted with comma(,)
#     list is represents as 'lst'.
# TUPLE:
# tuple is a collection of elements like a list
# it is immutable
# it denotes as a parenthassis() sepatered with comma(,)
#
# DIFFRENCE
# list is mutable
# its unordered
# it contains duplicate values
#
# Tuple
# tuple is a immutable
# its ordered
# it contains duplicate values
#
#
# 3)What does the ‘#’ symbol do in Python?
# it is a comment in python .it representd as '#'
# comment will write in any postion.
#
#
# 4)What is the difference between a Mutable datatype and an Immutable data type?
# mutable:
# mutable data types are to add,remove,updae the elements
#
# immutable data types are not add ,remove,update the elemtns in data types
#
# 5)What is the difference between a Set and Dictionary
# set :
# is a collection of elments in a data type
# it can be unordered values
# it exists only unique values
# no duplicate values in set
#
#
# Dicitionary:
# it is a collection of data type values
# it can be unorderd values
# it exists mulitiple values like arays,integers ,etc..
# it can duplicate the values bu not data sets
#
#
#
#
# 6)What is the difference between / and // in Python?
# This symbol is / float division point it is used to mulitiply the clucation when the coefficent is in only in float integer
#
# // it is useed to exact integer to the reaminder value like integer
#
# 7)how does python dictionary different form a list?
#
# dictionary is konwn as collection key value pairs and list is a collection of elements both are different.
#
#
# 8)how do i modify a string in python?
#
# replace() method.
#
# 9)what is index in python and its types?
#
# accessing specific element from a data index types:positive,negative.
#
# 10)what is negative index in python?
#
# negative index start from right to left.its stats from -1,-2,-3,etc.
#
# 11)what is the slicing in python?
#
# accessing particulatr group of elements in a data.
#
# 12)what are the keywords in python?
#
# keywords is known as reserverd words or special words.its not used as variables.total keywords 35 like if,else,for,etc.
#
# 13)what are the variables in python?
#
# variables are known as to store the elements,values,data.
#
# 14)explain the rules of creating variables?
#
# variables are alphanumaricals
# variables are can't start with digits
# variables are can't start with special characters excpet -
# can't take keywords as the variable
# it is case sensitive.
#
# 15)how to comment multiple lines in python?
#
# using # in start of the comment.
#
# 16)what does len() do and explain with example?
#
# len() to calculate the lenth of a string example: a='apple' len(a) ->5.
#
# 17)how to remove values from a python list?
#
# pop()method.
